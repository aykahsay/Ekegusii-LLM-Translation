# %% [markdown]
# # 19. AWS Real-Time Streaming Inference Engine\nThis notebook is part of the AWS Kinesis streaming health QA & translation pipeline.

# %%
import sys, os
sys.path.append('..')
from src.models.streaming_predictor import StreamingInferenceWorker

# %%
worker = StreamingInferenceWorker(model_name_or_endpoint='Qwen/Qwen2.5-7B-Instruct')
print('Streaming inference worker initialized.')

# %%
sample_batch = [{'formatted_prompt': 'Translate to Ekegusii: How to prevent malaria in children'}]
predictions = worker.predict_batch(sample_batch)
print('Prediction output:', predictions)
