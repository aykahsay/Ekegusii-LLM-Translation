# %% [markdown]
# # 🔬 07. Meta Llama-3.1 8B QLoRA Fine-Tuning
# **Ekegusii-LLM-Translation Project Notebook**

# %%
import torch
import pandas as pd
import numpy as np
print('PyTorch Version:', torch.__version__)
print('CUDA Available:', torch.cuda.is_available())
